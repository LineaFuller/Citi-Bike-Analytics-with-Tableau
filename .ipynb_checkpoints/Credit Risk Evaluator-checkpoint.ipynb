# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# %%
# Read CSV file into Pandas
train_df = pd.read_csv(Path('Resources/2019loans.csv'))
train_df.drop(columns = ['Unnamed: 0',
 'index'], inplace= True)
test_df = pd.read_csv(Path('Resources/2020Q1loans.csv'))
test_df.drop(columns = ['Unnamed: 0',
 'index'], inplace= True)

train_df.head()

# Create data

# Separated Targets and Inputs
y_train = train_df["loan_status"]
X_train = train_df.drop(columns = "loan_status")
y_test = test_df["loan_status"]
X_test = test_df.drop(columns = "loan_status")

# Loan status: low risk = 0, high risk = 1
def convert_status (x):
    if x == "low_risk":
        return 0
    return 1

y_test = y_test.map(convert_status)
y_train = y_train.map(convert_status)

# %%
test_df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    40000.0    0.0819       814.70       MORTGAGE    140000.0
# 1     6000.0    0.1524       208.70           RENT     55000.0
# 2     3600.0    0.1695       128.27           RENT     42000.0
# 3    20000.0    0.1524       478.33           RENT    100000.0
# 4     3600.0    0.1240       120.27           RENT     50000.0
#
#   verification_status loan_status pymnt_plan    dti  delinq_2yrs  ...  \
# 0        Not Verified    low_risk          n  19.75          0.0  ...
# 1        Not Verified    low_risk          n  11.52          2.0  ...
# 2        Not Verified    low_risk          n   6.74          0.0  ...
# 3        Not Verified    low_risk          n  12.13          0.0  ...
# 4        Not Verified    low_risk          n  16.08          0.0  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            97.7               0.0                   0.0        0.0
# ...

# %%
test_df["pymnt_plan"].unique()
# Out:
# array(['n'], dtype=object)

# %%
train_df["pymnt_plan"].unique()
# Out:
# array(['n'], dtype=object)

# %%
# Convert categorical data to numeric and separate target feature for training data

X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(X_test)
train_cols = X_train.columns.tolist()
test_cols = X_test.columns.tolist()
                         
# Looking for column to drop from training data
for i in train_cols:
    if i not in test_cols:
        print(i)

# dummy_train.drop(columns="debt_settlement_flag_Y", inplace = True)
# Out:
# debt_settlement_flag_Y

# %%
X_train.head()
# Out:
#    loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0    13375.0    0.1797       483.34    223000.0  29.99          0.0
# 1    21000.0    0.1308       478.68    123000.0  11.26          2.0
# 2    20000.0    0.1240       448.95    197000.0  11.28          0.0
# 3     3000.0    0.1240       100.22     45000.0  18.08          0.0
# 4    30000.0    0.1612      1056.49    133000.0  27.77          0.0
#
#    inq_last_6mths  open_acc  pub_rec  revol_bal  ...  \
# 0             0.0      15.0      0.0    39728.0  ...
# 1             0.0      16.0      0.0     9585.0  ...
# 2             0.0      12.0      0.0    16708.0  ...
# 3             0.0      12.0      1.0     8809.0  ...
# 4             2.0      13.0      0.0    65420.0  ...
#
#    verification_status_Verified  pymnt_plan_n  initial_list_status_f  \
# 0                             0             1                      0
# 1                             0             1                      0
# ...

# %%
X_test.head()
# Out:
#    loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0    40000.0    0.0819       814.70    140000.0  19.75          0.0
# 1     6000.0    0.1524       208.70     55000.0  11.52          2.0
# 2     3600.0    0.1695       128.27     42000.0   6.74          0.0
# 3    20000.0    0.1524       478.33    100000.0  12.13          0.0
# 4     3600.0    0.1240       120.27     50000.0  16.08          0.0
#
#    inq_last_6mths  open_acc  pub_rec  revol_bal  ...  \
# 0             1.0      18.0      0.0     9471.0  ...
# 1             0.0       8.0      0.0     1280.0  ...
# 2             0.0       6.0      0.0     4757.0  ...
# 3             2.0       7.0      0.0    12731.0  ...
# 4             3.0       6.0      0.0    10413.0  ...
#
#    verification_status_Source Verified  verification_status_Verified  \
# 0                                    0                             0
# 1                                    0                             0
# ...

# %%
# add missing dummy variables to testing set
X_test["debt_settlement_flag_Y"]=0

X_test.head()
# Out:
#    loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0    40000.0    0.0819       814.70    140000.0  19.75          0.0
# 1     6000.0    0.1524       208.70     55000.0  11.52          2.0
# 2     3600.0    0.1695       128.27     42000.0   6.74          0.0
# 3    20000.0    0.1524       478.33    100000.0  12.13          0.0
# 4     3600.0    0.1240       120.27     50000.0  16.08          0.0
#
#    inq_last_6mths  open_acc  pub_rec  revol_bal  ...  \
# 0             1.0      18.0      0.0     9471.0  ...
# 1             0.0       8.0      0.0     1280.0  ...
# 2             0.0       6.0      0.0     4757.0  ...
# 3             2.0       7.0      0.0    12731.0  ...
# 4             3.0       6.0      0.0    10413.0  ...
#
#    verification_status_Verified  pymnt_plan_n  initial_list_status_f  \
# 0                             0             1                      0
# 1                             0             1                      0
# ...

# %%
# Predicition!

#I think my logistic regression model will perform better than my random forests classifier because /
# the number of observations is lesser than the number of features and will provide a discrete outcome. 
#

# %%
# Train the Logistic Regression model on the unscaled data and print the model score

classifier = LogisticRegression()
classifier.fit(X_train, y_train)
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")


#
# Out:
# Training Data Score: 0.650328407224959
# Testing Data Score: 0.5165886856656742
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
# Train a Random Forest Classifier model and print the model score
clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_train, y_train)
print(f'Training Score: {clf.score(X_train, y_train)}')
print(f'Testing Score: {clf.score(X_test, y_test)}')
# Out:
# Training Score: 1.0
# Testing Score: 0.6450446618460229

# %%
# Outcome !

# Both of my outcomes were not great, but it appears my Random Forest Classifier model performed better

# %%
# Scale the data

scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Prediction !

# I predict that my logistic regression model will perform better because scaling helps overcome /
# overfitting to get better results.

# %%
# Train the Logistic Regression model on the scaled data and print the model score

classifier = LogisticRegression()
classifier.fit(X_train_scaled, y_train)
print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.7078817733990148
# Testing Data Score: 0.767333049766057
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score

clf = RandomForestClassifier(random_state=1, n_estimators=500).fit(X_train_scaled, y_train)
print(f'Training Score: {clf.score(X_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_test_scaled, y_test)}')
# Out:
# Training Score: 1.0
# Testing Score: 0.6454700127605274

# %%
# Outcome! 

# My logistic regression model performed better
